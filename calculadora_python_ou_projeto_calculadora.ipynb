# %% [markdown]
# <a href="https://colab.research.google.com/github/ze-2000/proj02_calculadora_cientifica/blob/main/calculadora_python_ou_projeto_calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 5.1	Etapa 1: Implementação das Operações Básicas
# Criação do Algoritmo:
# •	Passo 1: Solicitar ao usuário que insira o primeiro número.
# •	Passo 2: Solicitar ao usuário que insira o segundo número.
# •	Passo 3: Solicitar ao usuário que insira o operador (+, -, *, /).
# •	Passo 4: Realizar o cálculo com base no operador inserido.
# •	Passo 5: Exibir o resultado.

# %%
# Solicitar ao usuário que insira o primeiro número
num1 = float(input("Insira o primeiro número: "))

# Solicitar ao usuário que insira o segundo número
num2 = float(input("Insira o segundo número: "))

# Solicitar ao usuário que insira o operador
operador = input("Insira o operador (+, -, *, /): ")

# Realizar o cálculo com base no operador inserido
if operador == '+':
    resultado = num1 + num2
elif operador == '-':
    resultado = num1 - num2
elif operador == '*':
    resultado = num1 * num2
elif operador == '/':
    if num2 != 0:
        resultado = num1 / num2
    else:
        resultado = "Erro: Divisão por zero!"
else:
    resultado = "Operador inválido!"

# Exibir o resultado
print("Resultado:", resultado)

# %% [markdown]
# 5.2	Etapa 2: Refatoração com Funções para Operações Básicas
# Criação do Algoritmo:
# •	Passo 1: Definir funções para adição, subtração, multiplicação e divisão.
# •	Passo 2: Solicitar ao usuário que insira o primeiro número.
# •	Passo 3: Solicitar ao usuário que insira o segundo número.
# •	Passo 4: Solicitar ao usuário que insira o operador.
# •	Passo 5: Chamar a função correspondente com base no operador inserido.
# •	Passo 6: Exibir o resultado.

# %%
# Definir funções para adição, subtração, multiplicação e divisão
def adicao(a, b):
    return a + b

def subtracao(a, b):
    return a - b

def multiplicacao(a, b):
    return a * b

def divisao(a, b):
    if b != 0:
        return a / b
    else:
        return "Erro: Divisão por zero!"

# Solicitar ao usuário que insira o primeiro número
num1 = float(input("Insira o primeiro número: "))

# Solicitar ao usuário que insira o segundo número
num2 = float(input("Insira o segundo número: "))

# Solicitar ao usuário que insira o operador
operador = input("Insira o operador (+, -, *, /): ")

# Chamar a função correspondente com base no operador inserido
if operador == '+':
    resultado = adicao(num1, num2)
elif operador == '-':
    resultado = subtracao(num1, num2)
elif operador == '*':
    resultado = multiplicacao(num1, num2)
elif operador == '/':
    resultado = divisao(num1, num2)
else:
    resultado = "Operador inválido!"

# Exibir o resultado
print("Resultado:", resultado)

# %% [markdown]
# 5.3	Etapa 3: Validação da Entrada do Usuário
# Criação do Algoritmo:
# •	Passo 1: Verificar se os números inseridos são válidos (números).
# •	Passo 2: Verificar se o operador inserido é válido (+, -, *, /).
# •	Passo 3: Exibir mensagens de erro apropriadas para entradas inválidas.
# •	Passo 4: Tratar o erro de divisão por zero.

# %%
# Funções para operações básicas
def adicao(a, b):
    return a + b

def subtracao(a, b):
    return a - b

def multiplicacao(a, b):
    return a * b

def divisao(a, b):
    if b != 0:
        return a / b
    else:
        return "Erro: Divisão por zero!"

# Verificar se os números inseridos são válidos
try:
    num1 = float(input("Insira o primeiro número: "))
    num2 = float(input("Insira o segundo número: "))
except ValueError:
    print("Erro: Entrada inválida! Por favor, insira números válidos.")
    exit()

# Verificar se o operador inserido é válido
operador = input("Insira o operador (+, -, *, /): ")
if operador not in ['+', '-', '*', '/']:
    print("Erro: Operador inválido!")
    exit()

# Realizar o cálculo com base no operador inserido
if operador == '+':
    resultado = adicao(num1, num2)
elif operador == '-':
    resultado = subtracao(num1, num2)
elif operador == '*':
    resultado = multiplicacao(num1, num2)
elif operador == '/':
    resultado = divisao(num1, num2)

# Exibir o resultado
print("Resultado:", resultado)

# %% [markdown]
# 5.4	Etapa 4: Implementação das Operações Científicas
# Criação do Algoritmo:
# •	Passo 1: Importar o módulo math.
# •	Passo 2: Implementar funções para cálculos de potenciação, radiciação, trigonometria e logaritmos (pow, sqrt, sin, cos, tan, log).
# •	Passo 3: Solicitar ao usuário que insira o número para o cálculo científico.
# •	Passo 4: Solicitar ao usuário que insira o operador para o cálculo científico (**, sqrt, sin, cos, tan, log).
# •	Passo 5: Chamar a função correspondente do módulo math.
# •	Passo 6: Exibir o resultado.

# %%
import math

# Funções para cálculos científicos
def potencia(a, b):
    return math.pow(a, b)

def raiz(a):
    return math.sqrt(a)

def seno(a):
    return math.sin(math.radians(a))

def cosseno(a):
    return math.cos(math.radians(a))

def tangente(a):
    return math.tan(math.radians(a))

def logaritmo(a):
    return math.log(a)

# Solicitar ao usuário que insira o número para o cálculo científico
num = float(input("Insira o número: "))

# Solicitar ao usuário que insira o operador para o cálculo científico
operador = input("Insira o operador (**, sqrt, sin, cos, tan, log): ")

# Chamar a função correspondente do módulo math
if operador == '**':
    expoente = float(input("Insira o expoente: "))
    resultado = potencia(num, expoente)
elif operador == 'sqrt':
    resultado = raiz(num)
elif operador == 'sin':
    resultado = seno(num)
elif operador == 'cos':
    resultado = cosseno(num)
elif operador == 'tan':
    resultado = tangente(num)
elif operador == 'log':
    resultado = logaritmo(num)
else:
    resultado = "Operador inválido!"

# Exibir o resultado
print("Resultado:", resultado)
